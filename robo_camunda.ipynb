# %% [markdown]
# ## Automação de Backup dos arquivos do Camunda

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
import os
import requests

# %%
# Cria um service object com o caminho do driver
serv_obj=Service("C:\Drivers\chromedriver-win64\chromedriver.exe")

# Passa o objeto de serviço para o objeto driver
driver = webdriver.Chrome(service=serv_obj)

# %%
# Abre o link enviado
driver.get("https://modeler.camunda.io")
driver.implicitly_wait(0.5)
driver.maximize_window() # maximiza a janela do browser

# %%
## Locator by name
email_box = text_box = driver.find_element(by=By.NAME, value="username") #localilzador
email_box.clear()
email_box.send_keys("escprocessos.administracao@goias.gov.br") #insere o e-mail no campo

# %%
# Configure o caminho do ChromeDriver
#driver_path = '/Drivers/chromedriver-win64/chromedriver.exe' # Altere para o caminho do seu ChromeDriver
#download_directory = '/Users/glauco.bonturi/Downloads' # Altere para o diretório onde deseja salvar os arquivos

# %%
# Crie um navegador
# options = webdriver.ChromeOptions()
# preferences = {"download.default_directory": download_directory}
# options.add_experimental_option("prefs", preferences)

# driver = webdriver.Chrome(executable_path=driver_path, options=options)

# %%
# Inicializando a Service classes no Firefox
'''
driver = webdriver.Firefox()
service = webdriver.FirefoxService()
driver = webdriver.Firefox(service=service)
'''# help online: https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.annotate.html
# Out:
# '\ndriver = webdriver.Firefox()\nservice = webdriver.FirefoxService()\ndriver = webdriver.Firefox(service=service)\n'

# %%
# driver.get("https://www.python.org")

# %%
# driver.quit()
